# %% [markdown]
# # License
#
# This project is licensed under the GNU Affero General Public License v3.0. See the [LICENSE](LICENSE) file for details.

# %% [markdown]
# <h1 style="text-align: center; font-family: 'Arial', sans-serif; color: #2c3e50;">
#   <strong>Introduction to Neural Networks Programming and Applied Artificial Intelligence</strong>
# </h1>
#
#
#
# ---
#
#
#
# > <p style="text-align: center; font-family: 'Arial', sans-serif; color: #34495e; font-size: 18px;">
#   <strong>Course coordinator </strong><br>
#   David Gonzalez (gonzal@unizar.es)
# </p>
#
# > <p style="text-align: center; font-family: 'Arial', sans-serif; color: #34495e; font-size: 18px;">
#   <strong>Authors </strong><br>
#   </p>
#   Carlos Bermejo-Barbanoj
#   </p>
#   Alicia Tierz
#   </p>
#   Mikel M. Iparraguirre
#   </p>
#   Lucas Tesán
#   </p>
#   </p>
#   Pau Urdeitx
#
#
# ---

# %% [markdown]
# ![logos1.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Chapter 5: Model Optimization: Advanced Training Techniques
# ---
#
#
# > <p style="text-align: center; font-family: 'Arial', sans-serif; color: #34495e; font-size: 18px;">
#   <strong>Lecture</strong><br>
#   Mikel M. Iparraguirre
# </p>
#
# > <p style="text-align: center; font-family: 'Arial', sans-serif; color: #34495e; font-size: 18px;">
#   <strong>Notebook Authors</strong><br>
#   </p>
#   Mikel M. Iparraguirre
#     </p>
#   Pau Urdeitx
# </p>
#
#
# ---
# This notebook assumes familiarity with Python and basic programming concepts. Prior knowledge of neural networks is helpful but not required.

# %% [markdown]
# # 🔎 Deep Dive into Model Selection & Hyperparameter Tuning in Deep Learning
#
# Welcome to this hands-on notebook where we explore the art and science of building performant deep learning models through **model selection**, **hyperparameter tuning**, and **regularization techniques**.
#
# Using the classic **MNIST handwritten digits dataset**, we'll walk through a practical pipeline that mirrors real-world machine learning workflows. This notebook isn’t just about getting high accuracy—it’s about understanding the *why* behind each design choice.
#
# ---
#
# ### 🚀 How to Think Like a Good AI Engineer
#
# 📊 **Understand Your Data**: Analyze and **visualize data** to define our **machine learning problem**
#
# **Model Selection**:
#
# 1.  ✂️ **Data Splitting**: Best practices for dividing data into training, validation, and test sets
# 2. 🧪 **Hyperparameter Optimization**: find the best combination of hyperparameters to solve the Machine Learning Problem.
# 3. 🚀 **Final Training with Best Hyperparameters and Early Stopping**
#
# **Test Model**: Test the best model found with the Test data split
#
# **Digit-Classifier APP**: Test our model with our own data, the *TRUE TES*T.
#
#
# ---

# %% [markdown]
# ## 📊 Understand Your Data
#
#
# The **MNIST dataset** is a collection of 70,000 grayscale images of handwritten digits (0–9), each sized 28×28 pixels. It is widely used as a benchmark for image classification tasks in machine learning.
#
# In this notebook, we load a small **fraction** of the MNIST dataset to speed up experimentation and reduce training time, while still preserving meaningful insights.

# %% [markdown]
# #### ⏳ Loading MNIST dataset

# %%
# !pip install -q pytorch_lightning
# !pip install -q wandb
# !pip install plotly
# Out:
# Requirement already satisfied: plotly in c:\users\unizar\.conda\envs\j_2025\lib\site-packages (6.2.0)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\unizar\.conda\envs\j_2025\lib\site-packages (from plotly) (1.44.0)
# Requirement already satisfied: packaging in c:\users\unizar\.conda\envs\j_2025\lib\site-packages (from plotly) (24.2)

# %%
import os
import wandb
import torch
import torch.nn.functional as F
import pytorch_lightning as pl
from pytorch_lightning.loggers import WandbLogger
from torchvision import transforms, datasets
from torch.utils.data import DataLoader, random_split
from pytorch_lightning.callbacks import ModelCheckpoint
from sklearn.model_selection import train_test_split
from torchvision import transforms, datasets
from torch.utils.data import TensorDataset
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import numpy as np
from types import SimpleNamespace

# %%
def load_mnist(train=True):
    transform = transforms.ToTensor()
    mnist_train_full = datasets.MNIST(os.getcwd(), train=train, download=True, transform=transform)

    # Extract images and labels as tensors
    data = torch.stack([mnist_train_full[i][0] for i in range(len(mnist_train_full))])
    targets = torch.tensor([mnist_train_full[i][1] for i in range(len(mnist_train_full))])
    print()
    print(f"Loaded MNIST subset with {len(data):,} images.")
    print(f"Image tensor shape: {data.shape}")
    print(f"Labels tensor shape: {targets.shape}")

    return data, targets

# %%
images, targets = load_mnist()
# Out:
# Loaded MNIST subset with 60,000 images.
# Image tensor shape: torch.Size([60000, 1, 28, 28])
# Labels tensor shape: torch.Size([60000])

# %% [markdown]
# ### 👀 Visualising MNIST dataset

# %%
def visualize_dataset_sample(idx=0):
    """This function visualizes a
    single sample from the dataset by index."""
    # Plot
    plt.figure(figsize=(3,3))

    image = images[idx].squeeze()
    label = targets[idx].item()

    plt.imshow(image, cmap='gray')
    plt.title(f"Lable={label}", fontsize=10)
    plt.axis('off')

    plt.tight_layout()
    plt.show()


def plot_label_distribution(labels, title="Label Distribution"):
    """Plots a histogram of label counts to visualize class balance."""
    # Convert tensor to numpy for plotting
    label_array = labels.numpy()

    # Create histogram
    plt.figure(figsize=(8, 4))
    plt.hist(label_array, bins=range(11), align='left', rwidth=0.8, color='skyblue', edgecolor='black')

    # Add text and grid
    plt.title(title)
    plt.xlabel("Digit Label")
    plt.ylabel("Number of Samples")
    plt.xticks(range(10))
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# #### Visualize one sample and the labels distribution

# %%
# visualize one sample
smaple_index = 5
visualize_dataset_sample(idx=smaple_index)
# Call the function on the full set or on splits
plot_label_distribution(targets)

# %% [markdown]
# ## ✂️ Dataset Split: Making a Train/Validation set
#
# **Proper data splitting** is essential to ensure that the model is trained and validated on **distinct, representative subsets** of the data. This helps to:
# - 🔒 **prevent data leakage**
# - ⚖️ **reduce overfitting**
# - 📈 **produce reliable performance estimates**

# %% [markdown]
# We start with the available dataset. It’s important to realize that **this is all the data we have**, and we must **decide how to split it** into training and validation sets.
#
# To do this, we use `sklearn.model_selection.train_test_split`, which provides a flexible way to divide the data while optionally maintaining label distribution using **stratification**.
#
# 🧠 **Key point:**
# Choosing the right split ratio (e.g., 80/20 or 70/30) is part of the design decisions **students must make**. This decision impacts training quality and validation reliability of the model selection proces.
#
# Let’s now define our split!

# %%
# Define split ratio
validation_ratio = 0.25 # TODO

# Perform the split with stratification to maintain label balance
X_train, X_val, y_train, y_val = train_test_split(images, targets, test_size=validation_ratio, stratify=targets, random_state=42)

# Set as TensorDatasets
reduction_train = 0.1  # reduce training data
train_dataset_full = TensorDataset(X_train, y_train)
train_dataset = TensorDataset(X_train[:int(len(X_train)*reduction_train)], y_train[:int(len(X_train)*reduction_train)])
val_dataset = TensorDataset(X_val, y_val)

# Check the size of the splits
print(f"Train set: {len(train_dataset)} samples")
print(f"Validation set: {len(val_dataset)} samples")

# visualize distribution validation after splitting
plot_label_distribution(y_val, title='Distribution targets Train')
plot_label_distribution(y_val, title='Distribution targets Valid')
# Out:
# Train set: 4500 samples
# Validation set: 15000 samples

# %% [markdown]
# ## ⚡ Model Architecture

# %% [markdown]
# In this notebook, we use a **fully connected neural network (MLP)** to classify handwritten digits from the MNIST dataset.
#
# ### 🧠 Model Structure:
# - The network starts by **flattening** the 28×28 input image.
# - Then, it passes through one or more **hidden layers** with **ReLU activations**.
# - Finally, it outputs **10 logits** (one for each digit class).
#
# This structure is simple but effective for small image datasets like MNIST, and it allows us to explore the effect of **hyperparameters** such as:
# - Number of **hidden units**
# - Number of **layers**
# - **Learning rate**
# - **Optimizer** type (SGD or Adam).

# %%
# 1. Define the LightningModule
class LitMNIST(pl.LightningModule):
    def __init__(self, hidden=128, layers=2, lr=1e-3, dropout=0., optimizer='Adam'):
        super().__init__()
        # save hyperparameters
        self.save_hyperparameters()

        # set architecture
        model = [torch.nn.Flatten(),
                torch.nn.Linear(28 * 28, hidden),
                torch.nn.ReLU(),
                torch.nn.Dropout(p=dropout)]  # Dropout after each ReLU

        for i in range(layers - 2):
            model.append(torch.nn.Linear(hidden, hidden))
            model.append(torch.nn.ReLU())
            model.append(torch.nn.Dropout(p=dropout))  # Dropout after each ReLU

        model.append(torch.nn.Linear(hidden, 10))  # Final output layer without dropout

        self.model = torch.nn.Sequential(*model)

    def forward(self, x):
        return self.model(x)

    def training_step(self, batch, batch_idx):
        x, y = batch
        logits = self(x)
        loss = F.cross_entropy(logits, y)
        acc = (logits.argmax(dim=1) == y).float().mean()
        self.log("train_loss", loss, on_step=False, on_epoch=True)
        self.log("train_acc", acc, on_step=False, on_epoch=True)
        return loss

    def validation_step(self, batch, batch_idx):
        x, y = batch
        logits = self(x)
        loss = F.cross_entropy(logits, y)
        acc = (logits.argmax(dim=1) == y).float().mean()
        self.log("val_loss", loss, prog_bar=True)
        self.log("val_acc", acc, prog_bar=True)

    def configure_optimizers(self):
        if self.hparams.optimizer == 'SGD':
            optimizer = torch.optim.SGD(self.parameters(), lr=self.hparams.lr)
        else:
            optimizer = torch.optim.Adam(self.parameters(), lr=self.hparams.lr)
        return optimizer

    def predict_digit(self, x: torch.Tensor):
        self.eval()
        with torch.no_grad():
            logits = self(x)
            probs = F.softmax(logits, dim=1)
            pred = torch.argmax(probs, dim=1)
        return pred, probs[0][pred]

# %% [markdown]
# ## 🧠  Hyperparameter Optimization: W&B
#
#
# When training machine learning models, **finding the best hyperparameter configuration** is crucial for achieving good performance. Instead of manually testing every combination, tools like **Weights & Biases (W&B)** automate this process by performing an efficient **search over the configuration space**.
#
# With W&B, you can:
#
# - **Define a search space** of hyperparameters
# - **Run multiple training experiments** exploring different hyperparameter combinations.
# - **Track and visualize results** in real-time on an interactive dashboard.
# - **Identify the best configuration** based on your chosen evaluation metric (e.g., validation accuracy).
#
# This approach helps you **systematically optimize your model**!

# %% [markdown]
# It’s essential to set these three components clearly before starting the hyperparameter optimization.
#
# 1. **Hyperparameter search space** — specifying which parameters to explore and their possible values or ranges.
# 2. **Optimization goal** — choosing the metric to maximize or minimize (e.g., validation accuracy).
# 3. **Effective search method** — selecting how to explore the space (e.g., random search, grid search, Bayesian optimization).
#
#
# Here is the hyperparameter configuration space we explore in this notebook:
#
# | Hyperparameter           | Description                           | Example Values / Range    |
# |-------------------------|-------------------------------------|--------------------------|
# | **Number of Hidden Units** | Number of neurons in each hidden layer | 4 to 128 or to 1024               |
# | **Number of Layers**       | Total hidden layers in the network     | 2, 4, 8                  |
# | **Dropout**       | Probability of deactivating neurons     | 0 to 0.5              |
# | **Learning Rate (lr)**     | Step size for optimizer updates        | 1e-6 to 1e-1             |
# | **Optimizer Type**         | Algorithm to update weights             | SGD, Adam                |

# %% [markdown]
# ### 🐙 Sweep configuration
#
# To run a hyperparameter sweep with Weights & Biases (W&B), we must define a dictionary specifying:
#
# - The **effective search method**: how W&B explores the hyperparameter space (e.g., `"random"`, `"grid"`, `"bayes"`).
# - The **optimization goal**: the metric W&B will monitor and either maximize or minimize (e.g., `"metric_acc"`, `"loss"`).
# - The **hyperparameter search space**: the parameters to tune, their possible values or distributions.
#
# Here is an example sweep configuration dictionary for W&B.

# %%
hyperopt_sweep = {

    # Search method
    "method": "random", # G1: "random" | G2: "grid" | G3: "bayes" | G4: "student-search"

    # Hyperparameter Optimization Goal
    "metric": {
        "name": "val_acc", # "val_loss", "train_loss", "val_acc", "train_acc"
        "goal": "maximize", # "maximize", "minimize"
    },

    # Hyperparameter Search Space
    "parameters": {
        "lr": {
           "distribution": "log_uniform_values",
           "min": 1e-5,
           "max": 1e-1
        },
        "hidden": {
            "distribution": "q_uniform",
            "q": 8,
            "min": 16,
            "max": 512
        },
         "dropout": {
            "distribution": "q_uniform",
            "q": 0.01,
            "min": 0,
            "max": 0.5
        },
        "layers":{
            "values": [2, 4, 8],
        },
        "optimizer": {
            "values": ["Adam", "SGD"],
        }
    }
}

# %% [markdown]
# ### 🔀 Training and Evaluating Sampled Hyperparameter Sets
#
# Weights & Biases (W&B) **samples hyperparameter configurations** from the defined configuration space to train the model and evaluate its performance.
#
# Each sampled configuration is used to run a full training cycle, logging metrics such as loss and accuracy, so we can compare different settings and identify the best-performing combination.

# %%
def training_optimization(config=None):

    # Called by W&B sweep
    with wandb.init() as run:
        args = run.config

    # Logger
    wandb_logger = WandbLogger(
        project="mnist-sweep",
        name=f"layers={args.layers}_hidden={args.hidden}_lr={args.lr:.0e}_Opt={args.optimizer}_drop={args.dropout}",
        log_model=False
    )

    # Set seed
    pl.seed_everything(52, workers=True)

    # Data Loaders
    train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True, num_workers=4)
    val_loader = DataLoader(val_dataset, batch_size=64, shuffle=False, num_workers=4)

    # Model instantiation
    model = LitMNIST(hidden=args.hidden, layers=args.layers, dropout=args.dropout,
                     lr=args.lr, optimizer=args.optimizer)

    # Save best trained model
    checkpoint_callback = ModelCheckpoint(monitor="val_acc", mode="max", save_top_k=1)

    # Trainer
    trainer = pl.Trainer(
        accelerator="gpu" if torch.cuda.is_available() else "cpu",
        max_epochs=5,
        logger=wandb_logger,
        callbacks=[checkpoint_callback],
        deterministic=True,
        num_sanity_val_steps=0
    )

    # Fit
    trainer.fit(model, train_loader, val_loader)

# %% [markdown]
# ### 🚀 Launch Hyperparameter Optimization
#
# Once the sweep configuration is defined, we **create the sweep** in W&B, which sets up the experiment with the specified search space and optimization criteria.
#
# Next, we **run the sweep agent**, which automatically samples hyperparameter configurations and executes the training function for each trial. By setting `count`, we control how many configurations to evaluate.
#
# This process allows us to efficiently explore many hyperparameter combinations, track results, and identify the best-performing model settings.

# %%
# Create the sweep
hyperparam_optimization = wandb.sweep(hyperopt_sweep, project="mnist-hyperOpt")

# Run the agent
wandb.agent(hyperparam_optimization, function=training_optimization, count=20)
# Out:
# Create sweep with ID: co486juh
# Sweep URL: https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh
# wandb: Agent Starting Run: 1omdz1ps with config:
# wandb: 	dropout: 0.49
# wandb: 	hidden: 240
# wandb: 	layers: 8
# wandb: 	lr: 0.027955331419930896
# wandb: 	optimizer: Adam
# wandb: Currently logged in as: purdeitx (unizar-purdeitx) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.20.1
# Run data is saved locally in <code>f:\01.Jaca\wandb\run-20250630_094109-1omdz1ps</code>
# Syncing run <strong><a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/1omdz1ps' target="_blank">silver-sweep-1</a></strong> to <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh</a>
#  View project at <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt</a>
#  View sweep at <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh</a>
#  View run at <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/1omdz1ps' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/1omdz1ps</a>
#  View run <strong style="color:#cdcd00">silver-sweep-1</strong> at: <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/1omdz1ps' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/1omdz1ps</a><br> View project at: <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250630_094109-1omdz1ps\logs</code>
# Seed set to 52
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# You are using a CUDA device ('NVIDIA GeForce RTX 3060 Laptop GPU') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# Ignoring project 'mnist-sweep' when running a sweep.
# Tracking run with wandb version 0.20.1
# Run data is saved locally in <code>.\wandb\run-20250630_094113-1omdz1ps</code>
# Resuming run <strong><a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/1omdz1ps' target="_blank">layers=8_hidden=240_lr=3e-02_Opt=Adam_drop=0.49</a></strong> to <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh</a>
#  View project at <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt</a>
#  View sweep at <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh</a>
#  View run at <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/1omdz1ps' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/1omdz1ps</a>
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type       | Params | Mode
# ---------------------------------------------
# 0 | model | Sequential | 537 K  | train
# ---------------------------------------------
# 537 K     Trainable params
# 0         Non-trainable params
# 537 K     Total params
# 2.151     Total estimated model params size (MB)
# 24        Modules in train mode
# 0         Modules in eval mode
# wandb: WARNING Config item 'hidden' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'layers' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'lr' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'dropout' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'optimizer' was locked by 'sweep' (ignored update).
# c:\Users\UNIZAR\.conda\envs\J_2025\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:420: Consider setting `persistent_workers=True` in 'train_dataloader' to speed up the dataloader worker initialization.
# c:\Users\UNIZAR\.conda\envs\J_2025\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:420: Consider setting `persistent_workers=True` in 'val_dataloader' to speed up the dataloader worker initialization.
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# `Trainer.fit` stopped: `max_epochs=5` reached.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▃▃▅▅▆▆██</td></tr><tr><td>train_acc</td><td>█▂▁▃▂</td></tr><tr><td>train_loss</td><td>█▃▁▁▂</td></tr><tr><td>trainer/global_step</td><td>▁▁▃▃▄▄▆▆██</td></tr><tr><td>val_acc</td><td>█▁▁▁▁</td></tr><tr><td>val_loss</td><td>▁▄▅▅█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>4</td></tr><tr><td>train_acc</td><td>0.11844</td></tr><tr><td>train_loss</td><td>2.34587</td></tr><tr><td>trainer/global_step</td><td>354</td></tr><tr><td>val_acc</td><td>0.1124</td></tr><tr><td>val_loss</td><td>2.3049</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">layers=8_hidden=240_lr=3e-02_Opt=Adam_drop=0.49</strong> at: <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/1omdz1ps' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/1omdz1ps</a><br> View project at: <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250630_094113-1omdz1ps\logs</code>
# wandb: Agent Starting Run: 6rynlybi with config:
# wandb: 	dropout: 0.35000000000000003
# wandb: 	hidden: 376
# wandb: 	layers: 2
# wandb: 	lr: 5.422934205355462e-05
# wandb: 	optimizer: SGD
# Tracking run with wandb version 0.20.1
# Run data is saved locally in <code>f:\01.Jaca\wandb\run-20250630_094227-6rynlybi</code>
# Syncing run <strong><a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/6rynlybi' target="_blank">lively-sweep-2</a></strong> to <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh</a>
#  View project at <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt</a>
#  View sweep at <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh</a>
#  View run at <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/6rynlybi' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/6rynlybi</a>
#  View run <strong style="color:#cdcd00">lively-sweep-2</strong> at: <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/6rynlybi' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/6rynlybi</a><br> View project at: <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250630_094227-6rynlybi\logs</code>
# Seed set to 52
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Ignoring project 'mnist-sweep' when running a sweep.
# Tracking run with wandb version 0.20.1
# Run data is saved locally in <code>.\wandb\run-20250630_094230-6rynlybi</code>
# Resuming run <strong><a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/6rynlybi' target="_blank">layers=2_hidden=376_lr=5e-05_Opt=SGD_drop=0.35000000000000003</a></strong> to <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh</a>
#  View project at <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt</a>
#  View sweep at <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh</a>
#  View run at <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/6rynlybi' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/6rynlybi</a>
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type       | Params | Mode
# ---------------------------------------------
# 0 | model | Sequential | 298 K  | train
# ---------------------------------------------
# 298 K     Trainable params
# 0         Non-trainable params
# 298 K     Total params
# 1.196     Total estimated model params size (MB)
# 6         Modules in train mode
# 0         Modules in eval mode
# wandb: WARNING Config item 'hidden' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'layers' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'lr' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'dropout' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'optimizer' was locked by 'sweep' (ignored update).
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# `Trainer.fit` stopped: `max_epochs=5` reached.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▃▃▅▅▆▆██</td></tr><tr><td>train_acc</td><td>▁▁▄▄█</td></tr><tr><td>train_loss</td><td>█▆▇▅▁</td></tr><tr><td>trainer/global_step</td><td>▁▁▃▃▄▄▆▆██</td></tr><tr><td>val_acc</td><td>▁▃▅▆█</td></tr><tr><td>val_loss</td><td>█▆▄▃▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>4</td></tr><tr><td>train_acc</td><td>0.11511</td></tr><tr><td>train_loss</td><td>2.30282</td></tr><tr><td>trainer/global_step</td><td>354</td></tr><tr><td>val_acc</td><td>0.11047</td></tr><tr><td>val_loss</td><td>2.30286</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">layers=2_hidden=376_lr=5e-05_Opt=SGD_drop=0.35000000000000003</strong> at: <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/6rynlybi' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/6rynlybi</a><br> View project at: <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250630_094230-6rynlybi\logs</code>
# wandb: Agent Starting Run: 09do4lkj with config:
# wandb: 	dropout: 0.44
# wandb: 	hidden: 200
# wandb: 	layers: 4
# wandb: 	lr: 0.013661120021732923
# wandb: 	optimizer: SGD
# Tracking run with wandb version 0.20.1
# Run data is saved locally in <code>f:\01.Jaca\wandb\run-20250630_094334-09do4lkj</code>
# Syncing run <strong><a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/09do4lkj' target="_blank">unique-sweep-3</a></strong> to <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh</a>
#  View project at <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt</a>
#  View sweep at <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh</a>
#  View run at <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/09do4lkj' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/09do4lkj</a>
#  View run <strong style="color:#cdcd00">unique-sweep-3</strong> at: <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/09do4lkj' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/09do4lkj</a><br> View project at: <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250630_094334-09do4lkj\logs</code>
# Seed set to 52
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Ignoring project 'mnist-sweep' when running a sweep.
# Tracking run with wandb version 0.20.1
# Run data is saved locally in <code>.\wandb\run-20250630_094337-09do4lkj</code>
# Resuming run <strong><a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/09do4lkj' target="_blank">layers=4_hidden=200_lr=1e-02_Opt=SGD_drop=0.44</a></strong> to <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh</a>
#  View project at <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt</a>
#  View sweep at <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh</a>
#  View run at <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/09do4lkj' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/09do4lkj</a>
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type       | Params | Mode
# ---------------------------------------------
# 0 | model | Sequential | 239 K  | train
# ---------------------------------------------
# 239 K     Trainable params
# 0         Non-trainable params
# 239 K     Total params
# 0.958     Total estimated model params size (MB)
# 12        Modules in train mode
# 0         Modules in eval mode
# wandb: WARNING Config item 'hidden' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'layers' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'lr' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'dropout' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'optimizer' was locked by 'sweep' (ignored update).
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# `Trainer.fit` stopped: `max_epochs=5` reached.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▃▃▅▅▆▆██</td></tr><tr><td>train_acc</td><td>▁▃▂▆█</td></tr><tr><td>train_loss</td><td>█▆▅▃▁</td></tr><tr><td>trainer/global_step</td><td>▁▁▃▃▄▄▆▆██</td></tr><tr><td>val_acc</td><td>▁▁▁▂█</td></tr><tr><td>val_loss</td><td>█▇▅▃▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>4</td></tr><tr><td>train_acc</td><td>0.16578</td></tr><tr><td>train_loss</td><td>2.27836</td></tr><tr><td>trainer/global_step</td><td>354</td></tr><tr><td>val_acc</td><td>0.1492</td></tr><tr><td>val_loss</td><td>2.26956</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">layers=4_hidden=200_lr=1e-02_Opt=SGD_drop=0.44</strong> at: <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/09do4lkj' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/09do4lkj</a><br> View project at: <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250630_094337-09do4lkj\logs</code>
# wandb: Agent Starting Run: 6p1agnh7 with config:
# wandb: 	dropout: 0.26
# wandb: 	hidden: 440
# wandb: 	layers: 8
# wandb: 	lr: 0.002819320550715316
# wandb: 	optimizer: SGD
# Tracking run with wandb version 0.20.1
# Run data is saved locally in <code>f:\01.Jaca\wandb\run-20250630_094446-6p1agnh7</code>
# Syncing run <strong><a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/6p1agnh7' target="_blank">eager-sweep-4</a></strong> to <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh</a>
#  View project at <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt</a>
#  View sweep at <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh</a>
#  View run at <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/6p1agnh7' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/6p1agnh7</a>
#  View run <strong style="color:#cdcd00">eager-sweep-4</strong> at: <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/6p1agnh7' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/6p1agnh7</a><br> View project at: <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250630_094446-6p1agnh7\logs</code>
# Seed set to 52
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Ignoring project 'mnist-sweep' when running a sweep.
# Tracking run with wandb version 0.20.1
# Run data is saved locally in <code>.\wandb\run-20250630_094449-6p1agnh7</code>
# Resuming run <strong><a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/6p1agnh7' target="_blank">layers=8_hidden=440_lr=3e-03_Opt=SGD_drop=0.26</a></strong> to <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh</a>
#  View project at <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt</a>
#  View sweep at <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh</a>
#  View run at <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/6p1agnh7' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/6p1agnh7</a>
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type       | Params | Mode
# ---------------------------------------------
# 0 | model | Sequential | 1.5 M  | train
# ---------------------------------------------
# 1.5 M     Trainable params
# 0         Non-trainable params
# 1.5 M     Total params
# 6.056     Total estimated model params size (MB)
# 24        Modules in train mode
# 0         Modules in eval mode
# wandb: WARNING Config item 'hidden' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'layers' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'lr' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'dropout' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'optimizer' was locked by 'sweep' (ignored update).
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# `Trainer.fit` stopped: `max_epochs=5` reached.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▃▃▅▅▆▆██</td></tr><tr><td>train_acc</td><td>▃▂█▁▃</td></tr><tr><td>train_loss</td><td>██▄▂▁</td></tr><tr><td>trainer/global_step</td><td>▁▁▃▃▄▄▆▆██</td></tr><tr><td>val_acc</td><td>█▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▆▄▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>4</td></tr><tr><td>train_acc</td><td>0.10267</td></tr><tr><td>train_loss</td><td>2.30188</td></tr><tr><td>trainer/global_step</td><td>354</td></tr><tr><td>val_acc</td><td>0.09873</td></tr><tr><td>val_loss</td><td>2.30225</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">layers=8_hidden=440_lr=3e-03_Opt=SGD_drop=0.26</strong> at: <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/6p1agnh7' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/6p1agnh7</a><br> View project at: <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250630_094449-6p1agnh7\logs</code>
# wandb: Agent Starting Run: xn60y53l with config:
# wandb: 	dropout: 0.19
# wandb: 	hidden: 80
# wandb: 	layers: 8
# wandb: 	lr: 0.008156549616894744
# wandb: 	optimizer: SGD
# Tracking run with wandb version 0.20.1
# Run data is saved locally in <code>f:\01.Jaca\wandb\run-20250630_094558-xn60y53l</code>
# Syncing run <strong><a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/xn60y53l' target="_blank">vital-sweep-5</a></strong> to <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh</a>
#  View project at <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt</a>
#  View sweep at <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh</a>
#  View run at <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/xn60y53l' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/xn60y53l</a>
#  View run <strong style="color:#cdcd00">vital-sweep-5</strong> at: <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/xn60y53l' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/xn60y53l</a><br> View project at: <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250630_094558-xn60y53l\logs</code>
# Seed set to 52
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Ignoring project 'mnist-sweep' when running a sweep.
# Tracking run with wandb version 0.20.1
# Run data is saved locally in <code>.\wandb\run-20250630_094601-xn60y53l</code>
# Resuming run <strong><a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/xn60y53l' target="_blank">layers=8_hidden=80_lr=8e-03_Opt=SGD_drop=0.19</a></strong> to <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh</a>
#  View project at <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt</a>
#  View sweep at <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh</a>
#  View run at <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/xn60y53l' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/xn60y53l</a>
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type       | Params | Mode
# ---------------------------------------------
# 0 | model | Sequential | 102 K  | train
# ---------------------------------------------
# 102 K     Trainable params
# 0         Non-trainable params
# 102 K     Total params
# 0.410     Total estimated model params size (MB)
# 24        Modules in train mode
# 0         Modules in eval mode
# wandb: WARNING Config item 'hidden' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'layers' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'lr' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'dropout' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'optimizer' was locked by 'sweep' (ignored update).
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# `Trainer.fit` stopped: `max_epochs=5` reached.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▃▃▅▅▆▆██</td></tr><tr><td>train_acc</td><td>▁▃▅▇█</td></tr><tr><td>train_loss</td><td>█▅▅▂▁</td></tr><tr><td>trainer/global_step</td><td>▁▁▃▃▄▄▆▆██</td></tr><tr><td>val_acc</td><td>▁▁███</td></tr><tr><td>val_loss</td><td>█▆▄▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>4</td></tr><tr><td>train_acc</td><td>0.12044</td></tr><tr><td>train_loss</td><td>2.30113</td></tr><tr><td>trainer/global_step</td><td>354</td></tr><tr><td>val_acc</td><td>0.1124</td></tr><tr><td>val_loss</td><td>2.30305</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">layers=8_hidden=80_lr=8e-03_Opt=SGD_drop=0.19</strong> at: <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/xn60y53l' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/xn60y53l</a><br> View project at: <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250630_094601-xn60y53l\logs</code>
# wandb: Agent Starting Run: szaqah4f with config:
# wandb: 	dropout: 0.02
# wandb: 	hidden: 328
# wandb: 	layers: 2
# wandb: 	lr: 0.0005365207267085216
# wandb: 	optimizer: SGD
# Tracking run with wandb version 0.20.1
# Run data is saved locally in <code>f:\01.Jaca\wandb\run-20250630_094700-szaqah4f</code>
# Syncing run <strong><a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/szaqah4f' target="_blank">radiant-sweep-6</a></strong> to <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh</a>
#  View project at <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt</a>
#  View sweep at <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh</a>
#  View run at <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/szaqah4f' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/szaqah4f</a>
#  View run <strong style="color:#cdcd00">radiant-sweep-6</strong> at: <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/szaqah4f' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/szaqah4f</a><br> View project at: <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250630_094700-szaqah4f\logs</code>
# Seed set to 52
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Ignoring project 'mnist-sweep' when running a sweep.
# Tracking run with wandb version 0.20.1
# Run data is saved locally in <code>.\wandb\run-20250630_094703-szaqah4f</code>
# Resuming run <strong><a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/szaqah4f' target="_blank">layers=2_hidden=328_lr=5e-04_Opt=SGD_drop=0.02</a></strong> to <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh</a>
#  View project at <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt</a>
#  View sweep at <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh</a>
#  View run at <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/szaqah4f' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/szaqah4f</a>
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type       | Params | Mode
# ---------------------------------------------
# 0 | model | Sequential | 260 K  | train
# ---------------------------------------------
# 260 K     Trainable params
# 0         Non-trainable params
# 260 K     Total params
# 1.043     Total estimated model params size (MB)
# 6         Modules in train mode
# 0         Modules in eval mode
# wandb: WARNING Config item 'hidden' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'layers' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'lr' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'dropout' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'optimizer' was locked by 'sweep' (ignored update).
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# `Trainer.fit` stopped: `max_epochs=5` reached.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▃▃▅▅▆▆██</td></tr><tr><td>train_acc</td><td>▁▂▄▆█</td></tr><tr><td>train_loss</td><td>█▆▅▃▁</td></tr><tr><td>trainer/global_step</td><td>▁▁▃▃▄▄▆▆██</td></tr><tr><td>val_acc</td><td>▁▂▄▆█</td></tr><tr><td>val_loss</td><td>█▆▅▃▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>4</td></tr><tr><td>train_acc</td><td>0.22844</td></tr><tr><td>train_loss</td><td>2.25946</td></tr><tr><td>trainer/global_step</td><td>354</td></tr><tr><td>val_acc</td><td>0.23873</td></tr><tr><td>val_loss</td><td>2.25712</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">layers=2_hidden=328_lr=5e-04_Opt=SGD_drop=0.02</strong> at: <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/szaqah4f' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/szaqah4f</a><br> View project at: <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250630_094703-szaqah4f\logs</code>
# wandb: Agent Starting Run: utin3xbt with config:
# wandb: 	dropout: 0.47
# wandb: 	hidden: 408
# wandb: 	layers: 2
# wandb: 	lr: 0.05085931690910801
# wandb: 	optimizer: SGD
# Tracking run with wandb version 0.20.1
# Run data is saved locally in <code>f:\01.Jaca\wandb\run-20250630_094807-utin3xbt</code>
# Syncing run <strong><a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/utin3xbt' target="_blank">deep-sweep-7</a></strong> to <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh</a>
#  View project at <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt</a>
#  View sweep at <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh</a>
#  View run at <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/utin3xbt' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/utin3xbt</a>
#  View run <strong style="color:#cdcd00">deep-sweep-7</strong> at: <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/utin3xbt' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/utin3xbt</a><br> View project at: <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250630_094807-utin3xbt\logs</code>
# Seed set to 52
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Ignoring project 'mnist-sweep' when running a sweep.
# Tracking run with wandb version 0.20.1
# Run data is saved locally in <code>.\wandb\run-20250630_094810-utin3xbt</code>
# Resuming run <strong><a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/utin3xbt' target="_blank">layers=2_hidden=408_lr=5e-02_Opt=SGD_drop=0.47</a></strong> to <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh</a>
#  View project at <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt</a>
#  View sweep at <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh</a>
#  View run at <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/utin3xbt' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/utin3xbt</a>
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type       | Params | Mode
# ---------------------------------------------
# 0 | model | Sequential | 324 K  | train
# ---------------------------------------------
# 324 K     Trainable params
# 0         Non-trainable params
# 324 K     Total params
# 1.297     Total estimated model params size (MB)
# 6         Modules in train mode
# 0         Modules in eval mode
# wandb: WARNING Config item 'hidden' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'layers' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'lr' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'dropout' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'optimizer' was locked by 'sweep' (ignored update).
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# `Trainer.fit` stopped: `max_epochs=5` reached.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▃▃▅▅▆▆██</td></tr><tr><td>train_acc</td><td>▁▆▇██</td></tr><tr><td>train_loss</td><td>█▄▂▁▁</td></tr><tr><td>trainer/global_step</td><td>▁▁▃▃▄▄▆▆██</td></tr><tr><td>val_acc</td><td>▁▅▇▇█</td></tr><tr><td>val_loss</td><td>█▄▂▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>4</td></tr><tr><td>train_acc</td><td>0.85622</td></tr><tr><td>train_loss</td><td>0.51626</td></tr><tr><td>trainer/global_step</td><td>354</td></tr><tr><td>val_acc</td><td>0.87453</td></tr><tr><td>val_loss</td><td>0.46358</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">layers=2_hidden=408_lr=5e-02_Opt=SGD_drop=0.47</strong> at: <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/utin3xbt' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/utin3xbt</a><br> View project at: <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250630_094810-utin3xbt\logs</code>
# wandb: Agent Starting Run: 9rhmhuii with config:
# wandb: 	dropout: 0.1
# wandb: 	hidden: 312
# wandb: 	layers: 2
# wandb: 	lr: 0.00032537290453303483
# wandb: 	optimizer: Adam
# Tracking run with wandb version 0.20.1
# Run data is saved locally in <code>f:\01.Jaca\wandb\run-20250630_094909-9rhmhuii</code>
# Syncing run <strong><a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/9rhmhuii' target="_blank">denim-sweep-8</a></strong> to <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh</a>
#  View project at <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt</a>
#  View sweep at <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh</a>
#  View run at <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/9rhmhuii' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/9rhmhuii</a>
#  View run <strong style="color:#cdcd00">denim-sweep-8</strong> at: <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/9rhmhuii' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/9rhmhuii</a><br> View project at: <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250630_094909-9rhmhuii\logs</code>
# Seed set to 52
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Ignoring project 'mnist-sweep' when running a sweep.
# Tracking run with wandb version 0.20.1
# Run data is saved locally in <code>.\wandb\run-20250630_094912-9rhmhuii</code>
# Resuming run <strong><a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/9rhmhuii' target="_blank">layers=2_hidden=312_lr=3e-04_Opt=Adam_drop=0.1</a></strong> to <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh</a>
#  View project at <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt</a>
#  View sweep at <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh</a>
#  View run at <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/9rhmhuii' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/9rhmhuii</a>
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type       | Params | Mode
# ---------------------------------------------
# 0 | model | Sequential | 248 K  | train
# ---------------------------------------------
# 248 K     Trainable params
# 0         Non-trainable params
# 248 K     Total params
# 0.992     Total estimated model params size (MB)
# 6         Modules in train mode
# 0         Modules in eval mode
# wandb: WARNING Config item 'hidden' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'layers' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'lr' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'dropout' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'optimizer' was locked by 'sweep' (ignored update).
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# `Trainer.fit` stopped: `max_epochs=5` reached.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▃▃▅▅▆▆██</td></tr><tr><td>train_acc</td><td>▁▆▇██</td></tr><tr><td>train_loss</td><td>█▃▂▁▁</td></tr><tr><td>trainer/global_step</td><td>▁▁▃▃▄▄▆▆██</td></tr><tr><td>val_acc</td><td>▁▅▇██</td></tr><tr><td>val_loss</td><td>█▃▂▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>4</td></tr><tr><td>train_acc</td><td>0.90867</td></tr><tr><td>train_loss</td><td>0.34588</td></tr><tr><td>trainer/global_step</td><td>354</td></tr><tr><td>val_acc</td><td>0.89707</td></tr><tr><td>val_loss</td><td>0.36356</td></tr></table><br/></div></div>
# ...
# Find logs at: <code>.\wandb\run-20250630_100014-d3pt5ncm\logs</code>
# Seed set to 52
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Ignoring project 'mnist-sweep' when running a sweep.
# Tracking run with wandb version 0.20.1
# Run data is saved locally in <code>.\wandb\run-20250630_100017-d3pt5ncm</code>
# Resuming run <strong><a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/d3pt5ncm' target="_blank">layers=4_hidden=88_lr=6e-03_Opt=SGD_drop=0.17</a></strong> to <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh</a>
#  View project at <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt</a>
#  View sweep at <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh</a>
#  View run at <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/d3pt5ncm' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/d3pt5ncm</a>
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type       | Params | Mode
# ---------------------------------------------
# 0 | model | Sequential | 85.6 K | train
# ---------------------------------------------
# 85.6 K    Trainable params
# 0         Non-trainable params
# 85.6 K    Total params
# 0.343     Total estimated model params size (MB)
# 12        Modules in train mode
# 0         Modules in eval mode
# wandb: WARNING Config item 'hidden' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'layers' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'lr' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'dropout' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'optimizer' was locked by 'sweep' (ignored update).
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# `Trainer.fit` stopped: `max_epochs=5` reached.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▃▃▅▅▆▆██</td></tr><tr><td>train_acc</td><td>▁▂▃▅█</td></tr><tr><td>train_loss</td><td>█▆▅▃▁</td></tr><tr><td>trainer/global_step</td><td>▁▁▃▃▄▄▆▆██</td></tr><tr><td>val_acc</td><td>▁▁▂▆█</td></tr><tr><td>val_loss</td><td>█▆▅▃▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>4</td></tr><tr><td>train_acc</td><td>0.19089</td></tr><tr><td>train_loss</td><td>2.29655</td></tr><tr><td>trainer/global_step</td><td>354</td></tr><tr><td>val_acc</td><td>0.26227</td></tr><tr><td>val_loss</td><td>2.29497</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">layers=4_hidden=88_lr=6e-03_Opt=SGD_drop=0.17</strong> at: <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/d3pt5ncm' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/d3pt5ncm</a><br> View project at: <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250630_100017-d3pt5ncm\logs</code>
# wandb: Agent Starting Run: minlrnd4 with config:
# wandb: 	dropout: 0.37
# wandb: 	hidden: 160
# wandb: 	layers: 8
# wandb: 	lr: 0.0009164081410374094
# wandb: 	optimizer: SGD
# Tracking run with wandb version 0.20.1
# Run data is saved locally in <code>f:\01.Jaca\wandb\run-20250630_100120-minlrnd4</code>
# Syncing run <strong><a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/minlrnd4' target="_blank">fallen-sweep-19</a></strong> to <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh</a>
#  View project at <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt</a>
#  View sweep at <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh</a>
#  View run at <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/minlrnd4' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/minlrnd4</a>
#  View run <strong style="color:#cdcd00">fallen-sweep-19</strong> at: <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/minlrnd4' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/minlrnd4</a><br> View project at: <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250630_100120-minlrnd4\logs</code>
# Seed set to 52
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Ignoring project 'mnist-sweep' when running a sweep.
# Tracking run with wandb version 0.20.1
# Run data is saved locally in <code>.\wandb\run-20250630_100123-minlrnd4</code>
# Resuming run <strong><a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/minlrnd4' target="_blank">layers=8_hidden=160_lr=9e-04_Opt=SGD_drop=0.37</a></strong> to <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh</a>
#  View project at <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt</a>
#  View sweep at <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh</a>
#  View run at <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/minlrnd4' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/minlrnd4</a>
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type       | Params | Mode
# ---------------------------------------------
# 0 | model | Sequential | 281 K  | train
# ---------------------------------------------
# 281 K     Trainable params
# 0         Non-trainable params
# 281 K     Total params
# 1.127     Total estimated model params size (MB)
# 24        Modules in train mode
# 0         Modules in eval mode
# wandb: WARNING Config item 'hidden' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'layers' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'lr' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'dropout' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'optimizer' was locked by 'sweep' (ignored update).
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# `Trainer.fit` stopped: `max_epochs=5` reached.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▃▃▅▅▆▆██</td></tr><tr><td>train_acc</td><td>▅▁▄▅█</td></tr><tr><td>train_loss</td><td>▇█▁▆▂</td></tr><tr><td>trainer/global_step</td><td>▁▁▃▃▄▄▆▆██</td></tr><tr><td>val_acc</td><td>▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▆▄▃▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>4</td></tr><tr><td>train_acc</td><td>0.10956</td></tr><tr><td>train_loss</td><td>2.30409</td></tr><tr><td>trainer/global_step</td><td>354</td></tr><tr><td>val_acc</td><td>0.1022</td></tr><tr><td>val_loss</td><td>2.30398</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">layers=8_hidden=160_lr=9e-04_Opt=SGD_drop=0.37</strong> at: <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/minlrnd4' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/minlrnd4</a><br> View project at: <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250630_100123-minlrnd4\logs</code>
# wandb: Agent Starting Run: h2xjpzyo with config:
# wandb: 	dropout: 0.27
# wandb: 	hidden: 144
# wandb: 	layers: 8
# wandb: 	lr: 0.053103927553586325
# wandb: 	optimizer: SGD
# Tracking run with wandb version 0.20.1
# Run data is saved locally in <code>f:\01.Jaca\wandb\run-20250630_100233-h2xjpzyo</code>
# Syncing run <strong><a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/h2xjpzyo' target="_blank">graceful-sweep-20</a></strong> to <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh</a>
#  View project at <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt</a>
#  View sweep at <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh</a>
#  View run at <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/h2xjpzyo' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/h2xjpzyo</a>
#  View run <strong style="color:#cdcd00">graceful-sweep-20</strong> at: <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/h2xjpzyo' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/h2xjpzyo</a><br> View project at: <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250630_100233-h2xjpzyo\logs</code>
# Seed set to 52
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Ignoring project 'mnist-sweep' when running a sweep.
# Tracking run with wandb version 0.20.1
# Run data is saved locally in <code>.\wandb\run-20250630_100235-h2xjpzyo</code>
# Resuming run <strong><a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/h2xjpzyo' target="_blank">layers=8_hidden=144_lr=5e-02_Opt=SGD_drop=0.27</a></strong> to <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh</a>
#  View project at <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt</a>
#  View sweep at <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/sweeps/co486juh</a>
#  View run at <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/h2xjpzyo' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/h2xjpzyo</a>
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type       | Params | Mode
# ---------------------------------------------
# 0 | model | Sequential | 239 K  | train
# ---------------------------------------------
# 239 K     Trainable params
# 0         Non-trainable params
# 239 K     Total params
# 0.959     Total estimated model params size (MB)
# 24        Modules in train mode
# 0         Modules in eval mode
# wandb: WARNING Config item 'hidden' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'layers' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'lr' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'dropout' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'optimizer' was locked by 'sweep' (ignored update).
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# `Trainer.fit` stopped: `max_epochs=5` reached.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▃▃▅▅▆▆██</td></tr><tr><td>train_acc</td><td>█▁▁▁▁</td></tr><tr><td>train_loss</td><td>█▃▂▁▃</td></tr><tr><td>trainer/global_step</td><td>▁▁▃▃▄▄▆▆██</td></tr><tr><td>val_acc</td><td>▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▂▁▃▄█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>4</td></tr><tr><td>train_acc</td><td>0.12044</td></tr><tr><td>train_loss</td><td>2.30038</td></tr><tr><td>trainer/global_step</td><td>354</td></tr><tr><td>val_acc</td><td>0.1124</td></tr><tr><td>val_loss</td><td>2.30191</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">layers=8_hidden=144_lr=5e-02_Opt=SGD_drop=0.27</strong> at: <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/h2xjpzyo' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt/runs/h2xjpzyo</a><br> View project at: <a href='https://wandb.ai/unizar-purdeitx/mnist-hyperOpt' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-hyperOpt</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250630_100235-h2xjpzyo\logs</code>

# %% [markdown]
# ### 🚀 Final Training with Best Hyperparameters and Early Stopping
#
# After completing model selection, we now **retrain the model using the best hyperparameters** we found during tuning.
# This ensures that our final model builds on the most effective configuration identified.
#
# To further improve generalization and avoid overfitting, we apply **Early Stopping** during training:
#
# - ⏹️ **Early Stopping**: Monitors validation performance and **automatically stops training** when the model stops improving.
#   This prevents overfitting, reduces training time, and helps the model generalize better to unseen data.
#
# > ✅ With this setup, we make the most of our tuned hyperparameters while also controlling overfitting using Early Stopping.

# %% [markdown]
# #### Best hyperparamters

# %%
# best found hyperparamters
hidden = 512
layers = 2
dropout = 0.1
lr = 1e-3
optimizer = "Adam"

# %% [markdown]
# #### Early stopping callback

# %%
from pytorch_lightning.callbacks import EarlyStopping
from pytorch_lightning.callbacks import ModelCheckpoint

# early stopping callback
early_stopping = EarlyStopping(
    monitor="val_loss",     # Metric to monitor
    min_delta=0.00,         # Minimum change to qualify as improvement
    patience=5,            # Epochs with no improvement after which training will be stopped
    verbose=True,           # Print early stopping messages
    mode="min"              # "min" for loss, "max" for accuracy or similar
)

# %% [markdown]
# #### Train model

# %%
# Logger
wandb_logger = WandbLogger(
    project="mnist-best-hyperparam",
    name=f"layers={layers}_hidden={hidden}_lr={lr:.0e}_Opt={optimizer}",
    log_model=False
)

# Set seed
pl.seed_everything(52, workers=True)

# Data Loaders
train_loader = DataLoader(train_dataset_full, batch_size=64, shuffle=True, num_workers=4)
val_loader = DataLoader(val_dataset, batch_size=64, shuffle=False, num_workers=4)

# Model instantiation
model = LitMNIST(hidden=hidden, layers=layers, dropout=dropout,
                 lr=lr, optimizer=optimizer)

# Save best trained model
checkpoint_callback = ModelCheckpoint(monitor="val_loss", mode="min", save_top_k=1)


# Trainer
trainer = pl.Trainer(
    accelerator="gpu" if torch.cuda.is_available() else "cpu",
    max_epochs=50,
    logger=wandb_logger,
    callbacks=[checkpoint_callback, early_stopping],
    deterministic=True,
    num_sanity_val_steps=0
)

# Fit
trainer.fit(model, train_loader, val_loader)
# Out:
# Seed set to 52
# GPU available: True (cuda), used: True
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# HPU available: False, using: 0 HPUs
# You are using a CUDA device ('NVIDIA GeForce RTX 3060 Laptop GPU') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# You are using a CUDA device ('NVIDIA GeForce RTX 3060 Laptop GPU') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# wandb: Currently logged in as: purdeitx (unizar-purdeitx) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.20.1
# Run data is saved locally in <code>.\wandb\run-20250630_143610-r0s4z6a9</code>
# Syncing run <strong><a href='https://wandb.ai/unizar-purdeitx/mnist-best-hyperparam/runs/r0s4z6a9' target="_blank">layers=2_hidden=512_lr=1e-03_Opt=Adam</a></strong> to <a href='https://wandb.ai/unizar-purdeitx/mnist-best-hyperparam' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/unizar-purdeitx/mnist-best-hyperparam' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-best-hyperparam</a>
#  View run at <a href='https://wandb.ai/unizar-purdeitx/mnist-best-hyperparam/runs/r0s4z6a9' target="_blank">https://wandb.ai/unizar-purdeitx/mnist-best-hyperparam/runs/r0s4z6a9</a>
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type       | Params | Mode
# ---------------------------------------------
# 0 | model | Sequential | 407 K  | train
# ---------------------------------------------
# 407 K     Trainable params
# 0         Non-trainable params
# 407 K     Total params
# 1.628     Total estimated model params size (MB)
# 6         Modules in train mode
# 0         Modules in eval mode
#
#   | Name  | Type       | Params | Mode
# ---------------------------------------------
# 0 | model | Sequential | 407 K  | train
# ---------------------------------------------
# 407 K     Trainable params
# 0         Non-trainable params
# 407 K     Total params
# 1.628     Total estimated model params size (MB)
# 6         Modules in train mode
# 0         Modules in eval mode
# c:\Users\UNIZAR\.conda\envs\J_2025\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:420: Consider setting `persistent_workers=True` in 'train_dataloader' to speed up the dataloader worker initialization.
# c:\Users\UNIZAR\.conda\envs\J_2025\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:420: Consider setting `persistent_workers=True` in 'val_dataloader' to speed up the dataloader worker initialization.
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved. New best score: 0.166
# Metric val_loss improved. New best score: 0.166
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.050 >= min_delta = 0.0. New best score: 0.116
# Metric val_loss improved by 0.050 >= min_delta = 0.0. New best score: 0.116
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.022 >= min_delta = 0.0. New best score: 0.094
# Metric val_loss improved by 0.022 >= min_delta = 0.0. New best score: 0.094
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.007 >= min_delta = 0.0. New best score: 0.087
# Metric val_loss improved by 0.007 >= min_delta = 0.0. New best score: 0.087
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.002 >= min_delta = 0.0. New best score: 0.085
# Metric val_loss improved by 0.002 >= min_delta = 0.0. New best score: 0.085
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.006 >= min_delta = 0.0. New best score: 0.080
# Metric val_loss improved by 0.006 >= min_delta = 0.0. New best score: 0.080
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Monitored metric val_loss did not improve in the last 5 records. Best score: 0.080. Signaling Trainer to stop.
# Monitored metric val_loss did not improve in the last 5 records. Best score: 0.080. Signaling Trainer to stop.

# %% [markdown]
# # 🧪 Final Evaluation with Best Hyperparameters
#
# After experimenting with different settings, we selected the best combination of hyperparameters.
# We then trained the model for longer using **Early Stopping** to prevent overfitting for regularization.
#
# In this final step, we evaluate the trained model on the **MNIST test set** using `accuracy_score` from `sklearn.metrics`.
#
# This allows us to measure the model’s generalization performance on unseen data.
#
# The final test accuracy is printed below.

# %%
from sklearn.metrics import accuracy_score

images_test, tagets_test = load_mnist(train=False)
predictions_test, _ = model.predict_digit(images_test)

acc = accuracy_score(predictions_test, tagets_test)

# Print result
print(f"\n✅ Final Test Accuracy: {acc * 100:.2f}%")
print(f"Evaluated on {len(tagets_test):,} test images.")
# Out:
# Loaded MNIST subset with 10,000 images.
# Image tensor shape: torch.Size([10000, 1, 28, 28])
# Labels tensor shape: torch.Size([10000])
#
# ✅ Final Test Accuracy: 97.93%
# Evaluated on 10,000 test images.

# %% [markdown]
# # 📱 Handwritten Digit Classifier App
#
# ### Let's test the OUR model!
#
# We've now built an interactive **digit classification app** using our trained model!
# This app can take an image of a **handwritten digit (0–9)** and predict what number it represents.
#
# It uses the model we've trained on the MNIST dataset, which has learned to recognize digit patterns from thousands of examples.
#
# With just a single input image, the app returns:
#
# - 🔢 The **predicted digit**
# - 📊 The **confidence score** of the prediction
#
# > ✅ This is a practical demonstration of how deep learning models can be deployed in real-world applications like OCR (Optical Character Recognition), banking, postal systems, and more.

# %% [markdown]
# #### Classifier App

# %%
import tkinter as tk
from PIL import Image, ImageDraw, ImageOps

class DigitDrawer:
    def __init__(self, model, size=280):
        self.model = model.eval()
        self.size = size  # Canvas size (280x280 for MNIST scaling)
        self.window = tk.Tk()
        self.window.title("Draw a digit")

        self.canvas = tk.Canvas(self.window, width=self.size, height=self.size, bg='black')
        self.canvas.pack()

        self.image = Image.new("L", (self.size, self.size), 0)
        self.draw = ImageDraw.Draw(self.image)

        self.canvas.bind("<B1-Motion>", self.paint)

        # Buttons Frame
        button_frame = tk.Frame(self.window)
        button_frame.pack()

        self.done_button = tk.Button(button_frame, text="Done", command=self.predict_digit)
        self.done_button.grid(row=0, column=0, padx=5, pady=5)

        self.reset_button = tk.Button(button_frame, text="Reset", command=self.reset_canvas)
        self.reset_button.grid(row=0, column=1, padx=5, pady=5)

        self.result_label = tk.Label(self.window, text="", font=("Arial", 20))
        self.result_label.pack()

    def paint(self, event):
        x1, y1 = (event.x - 10), (event.y - 10)
        x2, y2 = (event.x + 10), (event.y + 10)
        self.canvas.create_oval(x1, y1, x2, y2, fill='white', outline='white')
        self.draw.ellipse([x1, y1, x2, y2], fill=255)

    def reset_canvas(self):
        self.canvas.delete("all")
        self.image = Image.new("L", (self.size, self.size), 0)
        self.draw = ImageDraw.Draw(self.image)
        self.result_label.config(text="")  # Clear prediction result

    def preprocess_image(self):
        img = self.image.copy()
        img = img.resize((28, 28))                # Resize to MNIST size
        img = transforms.ToTensor()(img)          # shape: [1, 28, 28], values in [0, 1]
        img = img.unsqueeze(0)                    # shape: [1, 1, 28, 28]
        return img

    def predict_digit(self):
        input_tensor = self.preprocess_image()
        prediction, probs = model.predict_digit(input_tensor)
        self.result_label.config(text=f"Predicted Digit: {prediction.item()} Probability: {probs.item()}")

app = DigitDrawer(model)
app.window.mainloop()

# %% [markdown]
# # **References**
# [1]. Ian Goodfellow and Yoshua Bengio and Aaron Courville. *Deep Learning*. Deep Learning (2016). [http://www.deeplearningbook.org](http://www.deeplearningbook.org)
#
# [2]. Weights & Biases Documentation. *Official guide and API reference for experiment tracking, sweeps, and visualization tools.*
#    [https://docs.wandb.ai](https://docs.wandb.ai)

# %% [markdown]
# # **License**
#
# This notebook is free software: you can redistribute it and/or modify it under the terms of the GNU Affero General Public License as published by the Free Software Foundation, either version 3 of the License, or (at your option) any later version.
#
# This notebook is distributed in the hope that it will be useful, but WITHOUT ANY WARRANTY; without even the implied warranty of MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE. See the GNU Affero General Public License for more details.
#
# You should have received a copy of the GNU Affero General Public License along with this notebook. If not, see <https://www.gnu.org/licenses/>.
